# %% [markdown]
# # **Idea: Fraud Detection**
# > *Project 3 Level 2*
#
# Dataset - /content/drive/MyDrive/creditcard.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importing modules

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

#To avoid warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading dataset

# %%
df = pd.read_csv("/content/drive/MyDrive/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# ### Dataset information

# %%
#Checking for null values
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#Dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
print(f"no.of rows = {df.shape[0]}")
print(f"no.of columns = {df.shape[1]}")
# Out:
# no.of rows = 284807
# no.of columns = 31

# %%
#Statistical measures of the data
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# ...

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#Countplot
splot = sns.countplot(x = 'Class', data = df)
for p in splot.patches:
  splot.annotate(format(p.get_height(), '.0f'),
   (p.get_x() + p.get_width() / 2., p.get_height()),
    ha = 'center', va = 'center', xytext = (0, 5),
    textcoords = 'offset points')
plt.title('Number of fraud vs non-fraud transcations (imbalanced)')
plt.xticks(range(2) , labels=['non-fraud', 'fraud'])
plt.show()

# %% [markdown]
# From the graph we can see that the data is highly imbalanced. This cause the model to be biased.

# %%
#heatmap
plt.figure(figsize = (25,20))
sns.heatmap(df.corr(), annot = True)
plt.title("Heapmap for imbalanced data")
plt.show()

# %%
#Spliting the data according to class column
non_fraud = df.loc[df['Class'] == 0]
fraud = df.loc[df['Class'] == 1]

#Printing the shape(rows, columns) of non-fraud and fraud dataset.
print('Non-Fraudulent Transcations: ', non_fraud.shape)
print('Fraudulent Transcations: ', fraud.shape)
# Out:
# Non-Fraudulent Transcations:  (284315, 31)
# Fraudulent Transcations:  (492, 31)

# %%
non_fraud_sample = non_fraud.sample(n = 492)
print('Sample Non-Fraudlent Transcations: ', non_fraud_sample.shape)
# Out:
# Sample Non-Fraudlent Transcations:  (492, 31)

# %%
#Creating new dataframe using the sample non-fraud data.
new_df = pd.concat([non_fraud_sample, fraud], ignore_index = True)
new_df
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0    147675.0  2.053311  0.089735 -1.681836  0.454212  0.298310 -0.953526
# 1     28592.0  1.523235 -0.956582  0.136734 -1.636419 -0.997906 -0.204950
# 2    140457.0  2.132056  0.006533 -2.445985 -0.276850  0.936317 -0.801487
# 3     65949.0 -0.724134  0.749436  0.718118 -1.383455 -0.090941 -0.241553
# 4    158767.0  0.056775  0.942823  0.289884 -0.611192  0.519063 -1.069055
# ..        ...       ...       ...       ...       ...       ...       ...
# 979  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 980  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 981  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 982  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 983  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#            V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
print(f"no.of rows = {new_df.shape[0]}")
print(f"no.of columns = {new_df.shape[1]}")
# Out:
# no.of rows = 984
# no.of columns = 31

# %%
new_df['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
#Countplot
splot = sns.countplot(x = 'Class', data = new_df)
for p in splot.patches:
  splot.annotate(format(p.get_height(), '.0f'),
   (p.get_x() + p.get_width() / 2., p.get_height()),
    ha = 'center', va = 'center', xytext = (0, 5),
    textcoords = 'offset points')
plt.title('Number of fraud vs non-fraud transcations (balanced)')
plt.xticks(range(2) , labels=['non-fraud', 'fraud'])
plt.show()

# %% [markdown]
# Now the data is balanced.

# %%
#heatmap
plt.figure(figsize = (25,20))
sns.heatmap(new_df.corr(), annot = True)
plt.title("Heatmap of balanced data")
plt.show()

# %% [markdown]
# ## Spliting the data

# %%
x = new_df.drop('Class', axis = 1) #Features
y = new_df['Class'] #Target

# %% [markdown]
# ## Train Test Spliting

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2,
                                                    random_state = 42,
                                                    stratify = y)

print(x_train.shape, x_test.shape)
# Out:
# (787, 30) (197, 30)

# %% [markdown]
# ## Model Building

# %%
#model building
log_reg = LogisticRegression()
log_reg.fit(x_train, y_train)

rf_clf = RandomForestClassifier()
rf_clf.fit(x_train, y_train)

y_pred1 = log_reg.predict(x_test)
y_pred2 = rf_clf.predict(x_test)

# %%
#classification report for logistic regression
print(f"{' '*18}Logistic Regression Report\n")
print(classification_report(y_test, y_pred1))
# Out:
#                   Logistic Regression Report
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95        99
#            1       0.95      0.96      0.95        98
#
#     accuracy                           0.95       197
#    macro avg       0.95      0.95      0.95       197
# weighted avg       0.95      0.95      0.95       197

# %%
#classification report for random forest classifier
print(f"{' '*16}Random Forest Classifier Report\n")
print(classification_report(y_test, y_pred2))
# Out:
#                 Random Forest Classifier Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95        99
#            1       0.96      0.95      0.95        98
#
#     accuracy                           0.95       197
#    macro avg       0.95      0.95      0.95       197
# weighted avg       0.95      0.95      0.95       197

# %% [markdown]
# In summary, the Logistic Regression and Random Forest Classifier model has proven effective in credit card fraud detection, providing a balance of accuracy and simplicity.

# %% [markdown]
# ---
